# %% [markdown]
# # ML MODEL WITH DATA IMPORTED FROM DATABASE

# %%
# Read in table of data from PGADMIN or connected database

from sqlalchemy import create_engine
#import library psycopyg2
import psycopg2
#import library sqlio
import pandas.io.sql as sqlio

# Postgres username, password, and database name
POSTGRES_ADDRESS = 'db1-realestate-prediction.cc3utfionj0h.us-east-2.rds.amazonaws.com' ## INSERT YOUR DB ADDRESS
POSTGRES_PORT = '5432'
POSTGRES_USERNAME = 'realestate'
POSTGRES_PASSWORD = '12345678'
POSTGRES_DBNAME = 'postgres'

#create database connection variable 
conn = psycopg2.connect(user=POSTGRES_USERNAME, password=POSTGRES_PASSWORD, host=POSTGRES_ADDRESS, database=POSTGRES_DBNAME)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
df_dbase = sqlio.read_sql_query('''SELECT * FROM public."REALESTATE";''', conn)
df_dbase
# Out:
#           id municipality                      community     list_price  \
# 0          0  Toronto C00                        Niagara    $699,999.00
# 1          1  Toronto C01                     University    $799,000.00
# 2          2  Toronto C01                     University    $799,000.00
# 3          3  Toronto C01                        Niagara    $899,000.00
# 4          4  Toronto C01                        Niagara    $899,000.00
# ...      ...          ...                            ...            ...
# 31857  31857  Toronto W10  Thistletown-Beaumonde Heights  $1,299,900.00
# 31858  31858  Toronto W10  Thistletown-Beaumonde Heights  $1,349,000.00
# 31859  31859  Toronto W10         West Humber-Clairville  $1,599,900.00
# 31860  31860  Toronto W10  Thistletown-Beaumonde Heights  $1,750,000.00
# 31861  31861  Toronto W10               Elms-Old Rexdale  $2,213,888.00
#
#           sold_price               type         style   br   er   wr fr  \
# 0        $780,000.00  Att/Row/Townhouse      2-Storey  3.0  0.0  1.0  N
# 1      $1,225,000.00      Semi-Detached      2-Storey  3.0  0.0  2.0  Y
# 2      $1,203,000.00      Semi-Detached      2-Storey  3.0  1.0  3.0  N
# 3        $959,000.00  Att/Row/Townhouse      2-Storey  3.0  0.0  2.0  Y
# 4      $1,073,000.00  Att/Row/Townhouse      2-Storey  2.0  0.0  2.0  N
# ...              ...                ...           ...  ...  ...  ... ..
# 31857  $1,300,000.00           Detached  1 1/2 Storey  4.0  2.0  3.0  N
# 31858  $1,365,000.00           Detached     Backsplit  4.0  1.0  2.0  N
# 31859  $1,600,000.00           Detached      2-Storey  4.0  0.0  4.0  Y
# 31860  $1,850,000.00           Detached     Backsplit  5.0  0.0  4.0  Y
# 31861  $2,213,500.00          Multiplex      2-Storey  6.0  0.0  6.0  N
#
#        kitchen  gar_type           ac heat contract_date    mls_id  \
# 0          1.0      None  Central Air  Gas    2021-01-13  C5083064
# 1          2.0      None         None  Gas    2020-05-29  C4773721
# 2          2.0      None         None  Gas    2020-11-05  C4979474
# 3          1.0      None  Central Air  Gas    2020-09-22  C4923168
# 4          1.0      None  Central Air  Gas    2020-11-10  C4985281
# ...        ...       ...          ...  ...           ...       ...
# 31857      1.0  Attached  Central Air  Gas    2021-10-03  W5391840
# 31858      1.0  Attached  Central Air  Gas    2021-11-12  W5430335
# 31859      1.0  Attached  Central Air  Gas    2021-12-17  W5458498
# 31860      1.0  Attached  Central Air  Gas    2021-12-02  W5447590
# 31861      3.0      None  Central Air  Gas    2021-11-03  W5422077
#
#                               address        lat        lng
# 0          793 Adelaide St W, Toronto  43.643807 -79.409426
# 1                75 Major St, Toronto  43.659648 -79.403456
# 2                81 Major St, Toronto  43.659777 -79.403505
# 3          784 Adelaide St W, Toronto  43.644117 -79.409249
# 4            16 Whitaker Ave, Toronto  43.643948 -79.406457
# ...                               ...        ...        ...
# 31857         8 Wardlaw Cres, Toronto  43.739635 -79.565621
# 31858  156 Thistle Down Blvd, Toronto  43.740987 -79.550545
# 31859        11 Woodlot Cres, Toronto  43.732902 -79.614069
# 31860     16 Forest Path Crt, Toronto  43.741928 -79.555623
# 31861          29 Hadrian Dr, Toronto  43.714866 -79.552596
#
# [31862 rows x 20 columns]

# %%
df_dbase['list_price'] = df_dbase['list_price'].replace('[\$,]', '', regex=True).astype(float)
df_dbase['sold_price'] = df_dbase['sold_price'].replace('[\$,]', '', regex=True).astype(float)
df_dbase.drop(['id'], axis=1, inplace = True)
df_dbase=df_dbase.dropna()
df_dbase.isnull().sum()
# Out:
# municipality     0
# community        0
# list_price       0
# sold_price       0
# type             0
# style            0
# br               0
# er               0
# wr               0
# fr               0
# kitchen          0
# gar_type         0
# ac               0
# heat             0
# contract_date    0
# mls_id           0
# address          0
# lat              0
# lng              0
# dtype: int64

# %%
df_dbase["lng"] = pd.to_numeric(df_dbase["lng"])
df_dbase["lat"] = pd.to_numeric(df_dbase["lat"])

df_dbase['contract_date'] = pd.to_datetime(df_dbase['contract_date'])
import datetime
import time
z_db=[]
for i in df_dbase['contract_date']:
    y_db = time.mktime(i.timetuple())
    z_db.append(y_db)
    
df_dbase['contract_date']=z_db

df_dbase.drop(['mls_id', 'address'], inplace=True, axis=1)

df_dbase
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       municipality                      community  list_price  sold_price  \
# 0      Toronto C00                        Niagara    699999.0    780000.0
# 1      Toronto C01                     University    799000.0   1225000.0
# 2      Toronto C01                     University    799000.0   1203000.0
# 3      Toronto C01                        Niagara    899000.0    959000.0
# 4      Toronto C01                        Niagara    899000.0   1073000.0
# ...            ...                            ...         ...         ...
# 31857  Toronto W10  Thistletown-Beaumonde Heights   1299900.0   1300000.0
# 31858  Toronto W10  Thistletown-Beaumonde Heights   1349000.0   1365000.0
# 31859  Toronto W10         West Humber-Clairville   1599900.0   1600000.0
# 31860  Toronto W10  Thistletown-Beaumonde Heights   1750000.0   1850000.0
# 31861  Toronto W10               Elms-Old Rexdale   2213888.0   2213500.0
#
#                     type         style   br   er   wr fr  kitchen  gar_type  \
# 0      Att/Row/Townhouse      2-Storey  3.0  0.0  1.0  N      1.0      None
# 1          Semi-Detached      2-Storey  3.0  0.0  2.0  Y      2.0      None
# 2          Semi-Detached      2-Storey  3.0  1.0  3.0  N      2.0      None
# 3      Att/Row/Townhouse      2-Storey  3.0  0.0  2.0  Y      1.0      None
# 4      Att/Row/Townhouse      2-Storey  2.0  0.0  2.0  N      1.0      None
# ...                  ...           ...  ...  ...  ... ..      ...       ...
# 31857           Detached  1 1/2 Storey  4.0  2.0  3.0  N      1.0  Attached
# 31858           Detached     Backsplit  4.0  1.0  2.0  N      1.0  Attached
# 31859           Detached      2-Storey  4.0  0.0  4.0  Y      1.0  Attached
# 31860           Detached     Backsplit  5.0  0.0  4.0  Y      1.0  Attached
# 31861          Multiplex      2-Storey  6.0  0.0  6.0  N      3.0      None
#
#                 ac heat  contract_date        lat        lng
# 0      Central Air  Gas   1.610514e+09  43.643807 -79.409426
# 1             None  Gas   1.590725e+09  43.659648 -79.403456
# 2             None  Gas   1.604552e+09  43.659777 -79.403505
# 3      Central Air  Gas   1.600747e+09  43.644117 -79.409249
# 4      Central Air  Gas   1.604984e+09  43.643948 -79.406457
# ...            ...  ...            ...        ...        ...
# 31857  Central Air  Gas   1.633234e+09  43.739635 -79.565621
# 31858  Central Air  Gas   1.636693e+09  43.740987 -79.550545
# 31859  Central Air  Gas   1.639717e+09  43.732902 -79.614069
# 31860  Central Air  Gas   1.638421e+09  43.741928 -79.555623
# 31861  Central Air  Gas   1.635912e+09  43.714866 -79.552596
#
# [30718 rows x 17 columns]

# %%
cat_db = df_dbase.dtypes[df_dbase.dtypes == "object"].index.tolist()
cat_db
# Out:
# ['municipality', 'community', 'type', 'style', 'fr', 'gar_type', 'ac', 'heat']

# %%
# define ordinal encoding
from sklearn.preprocessing import OrdinalEncoder
enc_db = OrdinalEncoder()
# transform data
# Fit and transform the OneHotEncoder using the categorical variable list
encode_df_db = pd.DataFrame(enc_db.fit_transform(df_dbase[cat_db]))

# Add the encoded variable names to the DataFrame
encode_df_db.columns = df_dbase[cat_db].columns

final_db = df_dbase.merge(encode_df_db,left_index=True, right_index=True)
final_db
# Out:
#       municipality_x                       community_x  list_price  \
# 0        Toronto C00                           Niagara    699999.0
# 1        Toronto C01                        University    799000.0
# 2        Toronto C01                        University    799000.0
# 3        Toronto C01                           Niagara    899000.0
# 4        Toronto C01                           Niagara    899000.0
# ...              ...                               ...         ...
# 30712    Toronto W09  Willowridge-Martingrove-Richview    899900.0
# 30713    Toronto W09  Willowridge-Martingrove-Richview    899900.0
# 30714    Toronto W09  Willowridge-Martingrove-Richview    899900.0
# 30715    Toronto W09  Willowridge-Martingrove-Richview    899900.0
# 30717    Toronto W09  Willowridge-Martingrove-Richview    899900.0
#
#        sold_price             type_x    style_x   br   er   wr fr_x  ...  \
# 0        780000.0  Att/Row/Townhouse   2-Storey  3.0  0.0  1.0    N  ...
# 1       1225000.0      Semi-Detached   2-Storey  3.0  0.0  2.0    Y  ...
# 2       1203000.0      Semi-Detached   2-Storey  3.0  1.0  3.0    N  ...
# 3        959000.0  Att/Row/Townhouse   2-Storey  3.0  0.0  2.0    Y  ...
# 4       1073000.0  Att/Row/Townhouse   2-Storey  2.0  0.0  2.0    N  ...
# ...           ...                ...        ...  ...  ...  ...  ...  ...
# 30712    950000.0           Detached   Bungalow  3.0  1.0  2.0    N  ...
# 30713    975000.0           Detached  Sidesplit  3.0  0.0  2.0    N  ...
# 30714    975000.0           Detached  Sidesplit  4.0  2.0  2.0    N  ...
# 30715    950000.0           Detached   Bungalow  3.0  0.0  1.0    N  ...
# 30717    985000.0           Detached   Bungalow  3.0  1.0  2.0    N  ...
#
#              lat        lng municipality_y community_y  type_y  style_y  fr_y  \
# 0      43.643807 -79.409426            0.0        91.0     0.0      2.0   0.0
# 1      43.659648 -79.403456            1.0       121.0     8.0      2.0   1.0
# 2      43.659777 -79.403505            1.0       121.0     8.0      2.0   0.0
# 3      43.644117 -79.409249            1.0        91.0     0.0      2.0   1.0
# 4      43.643948 -79.406457            1.0        91.0     0.0      2.0   0.0
# ...          ...        ...            ...         ...     ...      ...   ...
# 30712  43.689592 -79.557682           35.0       126.0     1.0      2.0   1.0
# 30713  43.683167 -79.560407           35.0       119.0     1.0      0.0   0.0
# 30714  43.690863 -79.558152           35.0       119.0     1.0      4.0   0.0
# 30715  43.681811 -79.561523           35.0       126.0     1.0      2.0   1.0
# 30717  43.689687 -79.560456           35.0        40.0     5.0      2.0   0.0
#
#        gar_type_y  ac_y  heat_y
# 0             4.0   0.0     1.0
# 1             4.0   1.0     1.0
# 2             4.0   1.0     1.0
# 3             4.0   0.0     1.0
# 4             4.0   0.0     1.0
# ...           ...   ...     ...
# 30712         0.0   0.0     1.0
# 30713         0.0   0.0     1.0
# 30714         0.0   0.0     1.0
# 30715         0.0   0.0     1.0
# 30717         4.0   0.0     1.0
#
# [29631 rows x 25 columns]

# %%
final_db.columns
# Out:
# Index(['municipality_x', 'community_x', 'list_price', 'sold_price', 'type_x',
#        'style_x', 'br', 'er', 'wr', 'fr_x', 'kitchen', 'gar_type_x', 'ac_x',
#        'heat_x', 'contract_date', 'lat', 'lng', 'municipality_y',
#        'community_y', 'type_y', 'style_y', 'fr_y', 'gar_type_y', 'ac_y',
#        'heat_y'],
#       dtype='object')

# %%
final_db = final_db.drop(['municipality_x', 'community_x', 'type_x', 'style_x', 'fr_x', 'gar_type_x', 'ac_x', 'heat_x'] ,1)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
# Split our preprocessed data into our features and target arrays
y = final_db["sold_price"].values
X = final_db.drop(["sold_price"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#Liner Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train_scaled, y_train)

y_predd = regressor.predict(X_test_scaled)

from sklearn import metrics
import numpy as np

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(y_test, y_predd))) 
print('Mean Squared Error:{:.2f}'.format(metrics.mean_squared_error(y_test, y_predd)))  
print('Root Mean Squared Error:{:.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, y_predd))))
print('Variance score is: {:.2f}'.format(metrics.explained_variance_score(y_test,y_predd)))
# Out:
# Mean Absolute Error: 111268.23
# Mean Squared Error:22085803464.58
# Root Mean Squared Error:148612.93
# Variance score is: 0.97

# %%
print('Linear Regression Model:')
print("Train Score {:.2f}".format(regressor.score(X_train_scaled,y_train)))
print("Test Score {:.2f}".format(regressor.score(X_test_scaled, y_test)))
# Out:
# Linear Regression Model:
# Train Score 0.97
# Test Score 0.97

# %% [markdown]
# # Create Neural Network Model

# %%
# Read in clean complete dataset with lat/lng
model_df = pd.read_csv('Resources_Cleaned/Inactive_Listings.csv')
model_df
# Out:
#        Unnamed: 0 Municipality                      Community List_Price($)  \
# 0               0  Toronto C00                        Niagara      $699,999
# 1               1  Toronto C01                     University      $799,000
# 2               2  Toronto C01                     University      $799,000
# 3               3  Toronto C01                        Niagara      $899,000
# 4               4  Toronto C01                        Niagara      $899,000
# ...           ...          ...                            ...           ...
# 31857       31857  Toronto W10  Thistletown-Beaumonde Heights    $1,299,900
# 31858       31858  Toronto W10  Thistletown-Beaumonde Heights    $1,349,000
# 31859       31859  Toronto W10         West Humber-Clairville    $1,599,900
# 31860       31860  Toronto W10  Thistletown-Beaumonde Heights    $1,750,000
# 31861       31861  Toronto W10               Elms-Old Rexdale    $2,213,888
#
#       Sold_Price($)               Type         Style   BR   ER  WR FR  \
# 0          $780,000  Att/Row/Townhouse      2-Storey  3.0  0.0   1  N
# 1        $1,225,000      Semi-Detached      2-Storey  3.0  0.0   2  Y
# 2        $1,203,000      Semi-Detached      2-Storey  3.0  1.0   3  N
# 3          $959,000  Att/Row/Townhouse      2-Storey  3.0  0.0   2  Y
# 4        $1,073,000  Att/Row/Townhouse      2-Storey  2.0  0.0   2  N
# ...             ...                ...           ...  ...  ...  .. ..
# 31857    $1,300,000           Detached  1 1/2 Storey  4.0  2.0   3  N
# 31858    $1,365,000           Detached     Backsplit  4.0  1.0   2  N
# 31859    $1,600,000           Detached      2-Storey  4.0  0.0   4  Y
# 31860    $1,850,000           Detached     Backsplit  5.0  0.0   4  Y
# 31861    $2,213,500          Multiplex      2-Storey  6.0  0.0   6  N
#
#        Kitchen  Gar_Type           AC Heat Contract_Date    MLS_ID  \
# 0          1.0      None  Central Air  Gas    2021-01-13  C5083064
# 1          2.0      None         None  Gas    2020-05-29  C4773721
# 2          2.0      None         None  Gas    2020-11-05  C4979474
# 3          1.0      None  Central Air  Gas    2020-09-22  C4923168
# 4          1.0      None  Central Air  Gas    2020-11-10  C4985281
# ...        ...       ...          ...  ...           ...       ...
# 31857      1.0  Attached  Central Air  Gas    2021-10-03  W5391840
# 31858      1.0  Attached  Central Air  Gas    2021-11-12  W5430335
# 31859      1.0  Attached  Central Air  Gas    2021-12-17  W5458498
# 31860      1.0  Attached  Central Air  Gas    2021-12-02  W5447590
# 31861      3.0      None  Central Air  Gas    2021-11-03  W5422077
#
#                               Address        Lat        Lng
# 0          793 Adelaide St W, Toronto  43.643807 -79.409426
# 1                75 Major St, Toronto  43.659648 -79.403456
# 2                81 Major St, Toronto  43.659777 -79.403505
# 3          784 Adelaide St W, Toronto  43.644117 -79.409249
# 4            16 Whitaker Ave, Toronto  43.643948 -79.406457
# ...                               ...        ...        ...
# 31857         8 Wardlaw Cres, Toronto  43.739635 -79.565621
# 31858  156 Thistle Down Blvd, Toronto  43.740987 -79.550545
# 31859        11 Woodlot Cres, Toronto  43.732902 -79.614069
# 31860     16 Forest Path Crt, Toronto  43.741928 -79.555623
# 31861          29 Hadrian Dr, Toronto  43.714866 -79.552596
#
# [31862 rows x 20 columns]

# %%
model_df['List_Price($)'] = model_df['List_Price($)'].replace('[\$,]', '', regex=True).astype(float)
model_df['Sold_Price($)'] = model_df['Sold_Price($)'].replace('[\$,]', '', regex=True).astype(float)
model_df.drop(['Unnamed: 0'], axis=1, inplace = True)
model_df=model_df.dropna()
model_df.isnull().sum()
# Out:
# Municipality     0
# Community        0
# List_Price($)    0
# Sold_Price($)    0
# Type             0
# Style            0
# BR               0
# ER               0
# WR               0
# FR               0
# Kitchen          0
# Gar_Type         0
# AC               0
# Heat             0
# Contract_Date    0
# MLS_ID           0
# Address          0
# Lat              0
# Lng              0
# dtype: int64

# %%
model_df["Lng"] = pd.to_numeric(model_df["Lng"])
model_df["Lat"] = pd.to_numeric(model_df["Lat"])
model_df.dtypes
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Municipality      object
# Community         object
# List_Price($)    float64
# Sold_Price($)    float64
# Type              object
# Style             object
# BR               float64
# ER               float64
# WR                 int64
# FR                object
# Kitchen          float64
# Gar_Type          object
# AC                object
# Heat              object
# Contract_Date     object
# MLS_ID            object
# Address           object
# Lat              float64
# Lng              float64
# dtype: object

# %%
model_df['Contract_Date'] = pd.to_datetime(model_df['Contract_Date'])
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
import datetime
import time
z=[]
for i in model_df['Contract_Date']:
    y = time.mktime(i.timetuple())
    z.append(y)
    
model_df['Contract_Date']=z
model_df
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Municipality                      Community  List_Price($)  \
# 0      Toronto C00                        Niagara       699999.0
# 1      Toronto C01                     University       799000.0
# 2      Toronto C01                     University       799000.0
# 3      Toronto C01                        Niagara       899000.0
# 4      Toronto C01                        Niagara       899000.0
# ...            ...                            ...            ...
# 31857  Toronto W10  Thistletown-Beaumonde Heights      1299900.0
# 31858  Toronto W10  Thistletown-Beaumonde Heights      1349000.0
# 31859  Toronto W10         West Humber-Clairville      1599900.0
# 31860  Toronto W10  Thistletown-Beaumonde Heights      1750000.0
# 31861  Toronto W10               Elms-Old Rexdale      2213888.0
#
#        Sold_Price($)               Type         Style   BR   ER  WR FR  \
# 0           780000.0  Att/Row/Townhouse      2-Storey  3.0  0.0   1  N
# 1          1225000.0      Semi-Detached      2-Storey  3.0  0.0   2  Y
# 2          1203000.0      Semi-Detached      2-Storey  3.0  1.0   3  N
# 3           959000.0  Att/Row/Townhouse      2-Storey  3.0  0.0   2  Y
# 4          1073000.0  Att/Row/Townhouse      2-Storey  2.0  0.0   2  N
# ...              ...                ...           ...  ...  ...  .. ..
# 31857      1300000.0           Detached  1 1/2 Storey  4.0  2.0   3  N
# 31858      1365000.0           Detached     Backsplit  4.0  1.0   2  N
# 31859      1600000.0           Detached      2-Storey  4.0  0.0   4  Y
# 31860      1850000.0           Detached     Backsplit  5.0  0.0   4  Y
# 31861      2213500.0          Multiplex      2-Storey  6.0  0.0   6  N
#
#        Kitchen  Gar_Type           AC Heat  Contract_Date    MLS_ID  \
# 0          1.0      None  Central Air  Gas   1.610514e+09  C5083064
# 1          2.0      None         None  Gas   1.590725e+09  C4773721
# 2          2.0      None         None  Gas   1.604552e+09  C4979474
# 3          1.0      None  Central Air  Gas   1.600747e+09  C4923168
# 4          1.0      None  Central Air  Gas   1.604984e+09  C4985281
# ...        ...       ...          ...  ...            ...       ...
# 31857      1.0  Attached  Central Air  Gas   1.633234e+09  W5391840
# 31858      1.0  Attached  Central Air  Gas   1.636693e+09  W5430335
# 31859      1.0  Attached  Central Air  Gas   1.639717e+09  W5458498
# 31860      1.0  Attached  Central Air  Gas   1.638421e+09  W5447590
# 31861      3.0      None  Central Air  Gas   1.635912e+09  W5422077
#
#                               Address        Lat        Lng
# 0          793 Adelaide St W, Toronto  43.643807 -79.409426
# 1                75 Major St, Toronto  43.659648 -79.403456
# 2                81 Major St, Toronto  43.659777 -79.403505
# 3          784 Adelaide St W, Toronto  43.644117 -79.409249
# 4            16 Whitaker Ave, Toronto  43.643948 -79.406457
# ...                               ...        ...        ...
# 31857         8 Wardlaw Cres, Toronto  43.739635 -79.565621
# 31858  156 Thistle Down Blvd, Toronto  43.740987 -79.550545
# 31859        11 Woodlot Cres, Toronto  43.732902 -79.614069
# 31860     16 Forest Path Crt, Toronto  43.741928 -79.555623
# 31861          29 Hadrian Dr, Toronto  43.714866 -79.552596
#
# [30718 rows x 19 columns]

# %%
model_df.drop(['MLS_ID', 'Address'], inplace=True, axis=1)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
cat = model_df.dtypes[model_df.dtypes == "object"].index.tolist()
cat
# Out:
# ['Municipality', 'Community', 'Type', 'Style', 'FR', 'Gar_Type', 'AC', 'Heat']

# %%
# define ordinal encoding
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
# transform data
# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(model_df[cat]))

# Add the encoded variable names to the DataFrame
encode_df.columns = model_df[cat].columns
encode_df.head()
# Out:
#    Municipality  Community  Type  Style   FR  Gar_Type   AC  Heat
# 0           0.0       91.0   0.0    2.0  0.0       4.0  0.0   1.0
# 1           1.0      121.0   8.0    2.0  1.0       4.0  1.0   1.0
# 2           1.0      121.0   8.0    2.0  0.0       4.0  1.0   1.0
# 3           1.0       91.0   0.0    2.0  1.0       4.0  0.0   1.0
# 4           1.0       91.0   0.0    2.0  0.0       4.0  0.0   1.0

# %%
final_df = model_df.merge(encode_df,left_index=True, right_index=True)
final_df
# Out:
#       Municipality_x                       Community_x  List_Price($)  \
# 0        Toronto C00                           Niagara       699999.0
# 1        Toronto C01                        University       799000.0
# 2        Toronto C01                        University       799000.0
# 3        Toronto C01                           Niagara       899000.0
# 4        Toronto C01                           Niagara       899000.0
# ...              ...                               ...            ...
# 30712    Toronto W09  Willowridge-Martingrove-Richview       899900.0
# 30713    Toronto W09  Willowridge-Martingrove-Richview       899900.0
# 30714    Toronto W09  Willowridge-Martingrove-Richview       899900.0
# 30716    Toronto W09  Willowridge-Martingrove-Richview       899900.0
# 30717    Toronto W09  Willowridge-Martingrove-Richview       899999.0
#
#        Sold_Price($)             Type_x    Style_x   BR   ER  WR FR_x  ...  \
# 0           780000.0  Att/Row/Townhouse   2-Storey  3.0  0.0   1    N  ...
# 1          1225000.0      Semi-Detached   2-Storey  3.0  0.0   2    Y  ...
# 2          1203000.0      Semi-Detached   2-Storey  3.0  1.0   3    N  ...
# 3           959000.0  Att/Row/Townhouse   2-Storey  3.0  0.0   2    Y  ...
# 4          1073000.0  Att/Row/Townhouse   2-Storey  2.0  0.0   2    N  ...
# ...              ...                ...        ...  ...  ...  ..  ...  ...
# 30712       975000.0           Detached  Sidesplit  3.0  0.0   2    N  ...
# 30713       975000.0           Detached  Sidesplit  4.0  2.0   2    N  ...
# 30714       950000.0           Detached   Bungalow  3.0  0.0   1    N  ...
# 30716       985000.0           Detached   Bungalow  3.0  1.0   2    N  ...
# 30717      1101000.0           Detached   Bungalow  3.0  1.0   2    N  ...
#
#              Lat        Lng Municipality_y Community_y  Type_y  Style_y  FR_y  \
# 0      43.643807 -79.409426            0.0        91.0     0.0      2.0   0.0
# 1      43.659648 -79.403456            1.0       121.0     8.0      2.0   1.0
# 2      43.659777 -79.403505            1.0       121.0     8.0      2.0   0.0
# 3      43.644117 -79.409249            1.0        91.0     0.0      2.0   1.0
# 4      43.643948 -79.406457            1.0        91.0     0.0      2.0   0.0
# ...          ...        ...            ...         ...     ...      ...   ...
# 30712  43.683167 -79.560407           35.0       126.0     1.0      2.0   1.0
# 30713  43.690863 -79.558152           35.0       119.0     1.0      0.0   0.0
# 30714  43.681811 -79.561523           35.0       119.0     1.0      4.0   0.0
# 30716  43.689687 -79.560456           35.0       119.0     1.0      4.0   1.0
# 30717  43.683482 -79.558879           35.0        40.0     5.0      2.0   0.0
#
#        Gar_Type_y  AC_y  Heat_y
# 0             4.0   0.0     1.0
# 1             4.0   1.0     1.0
# 2             4.0   1.0     1.0
# 3             4.0   0.0     1.0
# 4             4.0   0.0     1.0
# ...           ...   ...     ...
# 30712         0.0   0.0     1.0
# 30713         0.0   0.0     1.0
# 30714         0.0   0.0     1.0
# 30716         0.0   0.0     1.0
# 30717         4.0   0.0     1.0
#
# [29631 rows x 25 columns]

# %%
final_df.columns
# Out:
# Index(['Municipality_x', 'Community_x', 'List_Price($)', 'Sold_Price($)',
#        'Type_x', 'Style_x', 'BR', 'ER', 'WR', 'FR_x', 'Kitchen', 'Gar_Type_x',
#        'AC_x', 'Heat_x', 'Contract_Date', 'Lat', 'Lng', 'Municipality_y',
#        'Community_y', 'Type_y', 'Style_y', 'FR_y', 'Gar_Type_y', 'AC_y',
#        'Heat_y'],
#       dtype='object')

# %%
final_df = final_df.drop(['Municipality_x', 'Community_x', 'Type_x', 'Style_x', 'FR_x', 'Gar_Type_x', 'AC_x', 'Heat_x'] ,1)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
final_df
# Out:
#        List_Price($)  Sold_Price($)   BR   ER  WR  Kitchen  Contract_Date  \
# 0           699999.0       780000.0  3.0  0.0   1      1.0   1.610514e+09
# 1           799000.0      1225000.0  3.0  0.0   2      2.0   1.590725e+09
# 2           799000.0      1203000.0  3.0  1.0   3      2.0   1.604552e+09
# 3           899000.0       959000.0  3.0  0.0   2      1.0   1.600747e+09
# 4           899000.0      1073000.0  2.0  0.0   2      1.0   1.604984e+09
# ...              ...            ...  ...  ...  ..      ...            ...
# 30712       899900.0       975000.0  3.0  0.0   2      1.0   1.603685e+09
# 30713       899900.0       975000.0  4.0  2.0   2      1.0   1.604898e+09
# 30714       899900.0       950000.0  3.0  0.0   1      1.0   1.605071e+09
# 30716       899900.0       985000.0  3.0  1.0   2      1.0   1.612156e+09
# 30717       899999.0      1101000.0  3.0  1.0   2      1.0   1.603426e+09
#
#              Lat        Lng  Municipality_y  Community_y  Type_y  Style_y  \
# 0      43.643807 -79.409426             0.0         91.0     0.0      2.0
# 1      43.659648 -79.403456             1.0        121.0     8.0      2.0
# 2      43.659777 -79.403505             1.0        121.0     8.0      2.0
# 3      43.644117 -79.409249             1.0         91.0     0.0      2.0
# 4      43.643948 -79.406457             1.0         91.0     0.0      2.0
# ...          ...        ...             ...          ...     ...      ...
# 30712  43.683167 -79.560407            35.0        126.0     1.0      2.0
# 30713  43.690863 -79.558152            35.0        119.0     1.0      0.0
# 30714  43.681811 -79.561523            35.0        119.0     1.0      4.0
# 30716  43.689687 -79.560456            35.0        119.0     1.0      4.0
# 30717  43.683482 -79.558879            35.0         40.0     5.0      2.0
#
#        FR_y  Gar_Type_y  AC_y  Heat_y
# 0       0.0         4.0   0.0     1.0
# 1       1.0         4.0   1.0     1.0
# 2       0.0         4.0   1.0     1.0
# 3       1.0         4.0   0.0     1.0
# 4       0.0         4.0   0.0     1.0
# ...     ...         ...   ...     ...
# 30712   1.0         0.0   0.0     1.0
# 30713   0.0         0.0   0.0     1.0
# 30714   0.0         0.0   0.0     1.0
# 30716   1.0         0.0   0.0     1.0
# 30717   0.0         4.0   0.0     1.0
#
# [29631 rows x 17 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = final_df["Sold_Price($)"].values
X = final_df.drop(["Sold_Price($)"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Fit/Train Model on training data for inactive/sold houses

# %%
#Liner Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train_scaled, y_train)

#evaluate the model (intercept and slope)
regressor.intercept_
regressor.coef_
# Out:
# array([ 9.09271144e+05,  1.23482561e+04, -5.94543224e+03,  7.99364172e+03,
#        -1.20826196e+04,  4.17743739e+04, -3.10449918e+03, -3.18473938e+03,
#        -1.99788862e+04,  1.65092116e+03,  1.51305295e+03, -5.03043931e+03,
#        -3.44150662e+03,  1.06622213e+04,  9.47487277e+02,  1.89036802e+02])

# %%
y_predd = regressor.predict(X_test_scaled)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_predd})
df1 = df.head(10)
df1
# Out:
#       Actual     Predicted
# 0  1110000.0  1.145430e+06
# 1   760000.0  8.105215e+05
# 2  3149999.0  2.854585e+06
# 3  4850000.0  5.030945e+06
# 4  1300000.0  1.145267e+06
# 5  1250000.0  1.233565e+06
# 6  3150000.0  2.972766e+06
# 7  2800000.0  2.674277e+06
# 8  2820000.0  2.776142e+06
# 9  1375000.0  1.286633e+06

# %%
from sklearn import metrics
import numpy as np

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(y_test, y_predd))) 
print('Mean Squared Error:{:.2f}'.format(metrics.mean_squared_error(y_test, y_predd)))  
print('Root Mean Squared Error:{:.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, y_predd))))
print('Variance score is: {:.2f}'.format(metrics.explained_variance_score(y_test,y_predd)))
# Out:
# Mean Absolute Error: 112105.32
# Mean Squared Error:22751662974.16
# Root Mean Squared Error:150836.54
# Variance score is: 0.97

# %%
print('Linear Regression Model:')
print("Train Score {:.2f}".format(regressor.score(X_train_scaled,y_train)))
print("Test Score {:.2f}".format(regressor.score(X_test_scaled, y_test)))
# Out:
# Linear Regression Model:
# Train Score 0.97
# Test Score 0.97

# %% [markdown]
# # Model predicts on testing data for active listings

# %%
df2 = pd.read_csv('Resources_Uncleaned/Active_Listings_Raw.csv')
df2
# Out:
#      LSC  EC                         St#  Street Name  Abbr  Dir Municipality  \
# 0    New NaN             8 Virgilwood Dr          NaN   NaN  NaN  Toronto C07
# 1    New NaN        213 Northcliffe Blvd          NaN   NaN  NaN  Toronto C03
# 2    New NaN             144 Winnett Ave          NaN   NaN  NaN  Toronto C03
# 3    New NaN             357 Oakwood Ave          NaN   NaN  NaN  Toronto C03
# 4    New NaN               82 Petman Ave          NaN   NaN  NaN  Toronto C10
# ..   ...  ..                         ...          ...   ...  ...          ...
# 557  New NaN                9 Amaron Ave          NaN   NaN  NaN  Toronto W10
# 558  New NaN              35 Chilcot Ave          NaN   NaN  NaN  Toronto W10
# 559  New NaN          145 Silverstone Dr          NaN   NaN  NaN  Toronto W10
# 560  New NaN          107 Mount Olive Dr          NaN   NaN  NaN  Toronto W10
# 561  New NaN  8 & 10 Thistle Down Blvd E          NaN   NaN  NaN  Toronto W10
#
#                              Community  List Price              Type  ... Fam  \
# 0                  Westminster-Branson    $989,000     Semi-Detached  ...   N
# 1                      Oakwood-Vaughan    $999,900          Detached  ...   N
# 2                   Humewood-Cedarvale  $1,038,000     Semi-Detached  ...   N
# 3                      Oakwood-Vaughan  $1,145,000  Store w/Apt/Offc  ...   N
# 4                  Mount Pleasant East  $1,149,000          Detached  ...   N
# ..                                 ...         ...               ...  ...  ..
# 557      Thistletown-Beaumonde Heights  $1,049,900          Detached  ...   Y
# 558                   Elms-Old Rexdale  $1,199,999          Detached  ...   Y
# 559  Mount Olive-Silverstone-Jamestown  $1,231,000          Detached  ...   Y
# 560  Mount Olive-Silverstone-Jamestown  $1,279,000          Detached  ...   N
# 561      Thistletown-Beaumonde Heights  $2,600,000     Semi-Detached  ...   N
#
#      Kit  Gar Type        (A/C) Heat  Contract Date        List Brokerage  \
# 0    2.0      None  Central Air  Gas      12/17/2021  RE/MAX PREMIER I...
# 1    1.0  Detached  Window Unit  Gas        1/9/2022  RE/MAX REALTRON ...
# 2    1.0      None  Central Air  Gas       1/10/2022  ROYAL LEPAGE/J &...
# 3    3.0      None    Wall Unit  Gas      10/13/2021  FOREST HILL REAL...
# 4    1.0      None  Central Air  Gas       1/11/2022  CHESTNUT PARK RE...
# ..   ...       ...          ...  ...             ...                  ...
# 557  1.0  Detached  Central Air  Gas       1/10/2022  RE/MAX PREMIER I...
# 558  1.0  Detached  Central Air  Gas      11/27/2021  HOMELIFE LANDMAR...
# 559  1.0  Detached  Central Air  Gas        1/7/2022  HOMELIFE/MIRACLE...
# 560  1.0  Attached  Central Air  Gas        1/8/2022  RE/MAX COMMUNITY...
# 561  2.0      None  Central Air  Gas       1/10/2022  ROYAL LEPAGE TER...
#
#     Co-Op Brokerage         CB Com     MLS #
# 0      416-987-8000          2.25%  C5457674
# 1      905-470-9800          2.50%  C5467990
# 2      416-489-2121  2.5% + H.S...  C5468205
# 3      905-237-7427       2.5%+Hst  C5400499
# 4      416-925-9191     2.5% + Hst  C5469304
# ..              ...            ...       ...
# 557    416-743-2000          2.5 %  W5468541
# 558    905-305-1600          2.50%  W5443512
# 559    416-747-9777     2.5%-199Mf  W5467290
# 560    416-287-2222          2.50%  W5467611
# 561    416-495-4061          2.50%  W5468712
#
# [562 rows x 24 columns]

# %%
# Check for null values within the dataframe
df2.isnull().sum()
# Out:
# LSC                  0
# EC                 562
# St#                  0
# Street Name        562
# Abbr               562
# Dir                562
# Municipality         0
# Community            0
# List Price           0
# Type                 0
# Style               10
# BR                  10
# (+)                214
# Wr                   0
# Fam                 14
# Kit                 10
# Gar Type             7
# (A/C)                9
# Heat                 9
# Contract Date        0
# List Brokerage       0
# Co-Op Brokerage      0
# CB Com               0
# MLS #                0
# dtype: int64

# %%
# Convert all NaNs in the Extra Room column / (+) to 0s
df2['(+)'] = df2['(+)'].fillna(0)

# drop LSC, EC, Street Names, Abbr, Dir, List/Coop Brokerage and Sold Date.
# We remove sold date as feature as sold date does not exist in active listings dataset(the data we want predictions on)
df2.drop(['LSC', 'EC', 'Street Name', 'Abbr', 'Dir', 'List Brokerage', 'Co-Op Brokerage', 'CB Com', 'MLS #'], axis=1, inplace=True)

# %%
df2.isnull().sum()
# Out:
# St#                0
# Municipality       0
# Community          0
# List Price         0
# Type               0
# Style             10
# BR                10
# (+)                0
# Wr                 0
# Fam               14
# Kit               10
# Gar Type           7
# (A/C)              9
# Heat               9
# Contract Date      0
# dtype: int64

# %%
df2 = df2.dropna()
df2.isnull().sum()
# Out:
# St#               0
# Municipality      0
# Community         0
# List Price        0
# Type              0
# Style             0
# BR                0
# (+)               0
# Wr                0
# Fam               0
# Kit               0
# Gar Type          0
# (A/C)             0
# Heat              0
# Contract Date     0
# dtype: int64

# %%
df2
# Out:
#                             St# Municipality  \
# 0               8 Virgilwood Dr  Toronto C07
# 1          213 Northcliffe Blvd  Toronto C03
# 2               144 Winnett Ave  Toronto C03
# 3               357 Oakwood Ave  Toronto C03
# 4                 82 Petman Ave  Toronto C10
# ..                          ...          ...
# 557                9 Amaron Ave  Toronto W10
# 558              35 Chilcot Ave  Toronto W10
# 559          145 Silverstone Dr  Toronto W10
# 560          107 Mount Olive Dr  Toronto W10
# 561  8 & 10 Thistle Down Blvd E  Toronto W10
#
#                              Community  List Price              Type  \
# 0                  Westminster-Branson    $989,000     Semi-Detached
# 1                      Oakwood-Vaughan    $999,900          Detached
# 2                   Humewood-Cedarvale  $1,038,000     Semi-Detached
# 3                      Oakwood-Vaughan  $1,145,000  Store w/Apt/Offc
# 4                  Mount Pleasant East  $1,149,000          Detached
# ..                                 ...         ...               ...
# 557      Thistletown-Beaumonde Heights  $1,049,900          Detached
# 558                   Elms-Old Rexdale  $1,199,999          Detached
# 559  Mount Olive-Silverstone-Jamestown  $1,231,000          Detached
# 560  Mount Olive-Silverstone-Jamestown  $1,279,000          Detached
# 561      Thistletown-Beaumonde Heights  $2,600,000     Semi-Detached
#
#             Style   BR  (+)  Wr Fam  Kit  Gar Type        (A/C) Heat  \
# 0        Bungalow  4.0  2.0   2   N  2.0      None  Central Air  Gas
# 1        2-Storey  3.0  0.0   2   N  1.0  Detached  Window Unit  Gas
# 2        2-Storey  3.0  0.0   3   N  1.0      None  Central Air  Gas
# 3        2-Storey  3.0  0.0   3   N  3.0      None    Wall Unit  Gas
# 4        2-Storey  3.0  0.0   2   N  1.0      None  Central Air  Gas
# ..            ...  ...  ...  ..  ..  ...       ...          ...  ...
# 557      Bungalow  3.0  1.0   3   Y  1.0  Detached  Central Air  Gas
# 558  1 1/2 Storey  3.0  2.0   2   Y  1.0  Detached  Central Air  Gas
# 559      Bungalow  4.0  2.0   2   Y  1.0  Detached  Central Air  Gas
# 560      2-Storey  4.0  1.0   3   N  1.0  Attached  Central Air  Gas
# 561      Bungalow  6.0  3.0   4   N  2.0      None  Central Air  Gas
#
#     Contract Date
# 0       12/17/2021
# 1         1/9/2022
# 2        1/10/2022
# 3       10/13/2021
# 4        1/11/2022
# ..             ...
# 557      1/10/2022
# 558     11/27/2021
# 559       1/7/2022
# 560       1/8/2022
# 561      1/10/2022
#
# [547 rows x 15 columns]

# %%
# rename some columns
df2 = df2.rename(columns={'St#': 'Address', '(+)':'ER', 'Wr': 'WR', 'Fam': 'FR', 'Kit':'Kitchen', 'Contract Date ': 'Contract_Date', 'Gar Type': 'Gar_Type', '(A/C)':'AC'})

# %%
# Add Toronto to all the street addresses so when the code to find lat/lng runs it will only find addresses in GTA
df2['Address'] = df2['Address'].astype(str) + ', Toronto'

# %%
# resetting the DataFrame index
df2 = df2.reset_index()
df2.drop(['index'], axis=1, inplace=True)

# convert time to date time
df2['Contract_Date'] = pd.to_datetime(df2['Contract_Date'])
df2 = df2.rename(columns={'List Price': 'List_Price($)'})
df2.dtypes
# Out:
# Address                  object
# Municipality             object
# Community                object
# List_Price($)            object
# Type                     object
# Style                    object
# BR                      float64
# ER                      float64
# WR                        int64
# FR                       object
# Kitchen                 float64
# Gar_Type                 object
# AC                       object
# Heat                     object
# Contract_Date    datetime64[ns]
# dtype: object

# %%
data=[]
s=[]
f=[]
for i in df2['Address']:
    try: 
        url = "https://nominatim.openstreetmap.org/?addressdetails=1&q=" + i + "+" +"&format=json&limit=1"
        response = requests.get(url).json()
        data.append({"Address":i, "Lat": response[0]["lat"], "Lng": response[0]["lon"]})
        s.append(i)
    except:
        data.append({"Address":i, "Lat": np.NaN, "Lng": np.NaN})
        f.append(i)

# %%
print(len(s))
print(len(f))
# Out:
# 530
# 17

# %%
data2_df = pd.DataFrame(data)
data2_df.isnull().sum()
# Out:
# Address     0
# Lat        17
# Lng        17
# dtype: int64

# %%
data2_df
# Out:
#                                  Address                 Lat  \
# 0               8 Virgilwood Dr, Toronto           43.773367
# 1          213 Northcliffe Blvd, Toronto        43.682526175
# 2               144 Winnett Ave, Toronto         43.68782725
# 3               357 Oakwood Ave, Toronto         43.68699204
# 4                 82 Petman Ave, Toronto   43.70916151428571
# ..                                   ...                 ...
# 542                9 Amaron Ave, Toronto       43.7418921625
# 543              35 Chilcot Ave, Toronto          43.7141594
# 544          145 Silverstone Dr, Toronto  43.751753671986975
# 545          107 Mount Olive Dr, Toronto          43.7462574
# 546  8 & 10 Thistle Down Blvd E, Toronto  40.360960649999996
#
#                     Lng
# 0           -79.4485395
# 1           -79.4422434
# 2          -79.43277225
# 3          -79.43844438
# 4    -79.38486365714286
# ..                  ...
# 542      -79.5787170875
# 543         -79.5488803
# 544  -79.59027921260754
# 545         -79.5919673
# 546         116.0158654
#
# [547 rows x 3 columns]

# %%
merge2_df = df2.merge(data2_df, how = 'inner', left_index=True, right_index=True)
merge2_df
# Out:
#                                Address_x Municipality  \
# 0               8 Virgilwood Dr, Toronto  Toronto C07
# 1          213 Northcliffe Blvd, Toronto  Toronto C03
# 2               144 Winnett Ave, Toronto  Toronto C03
# 3               357 Oakwood Ave, Toronto  Toronto C03
# 4                 82 Petman Ave, Toronto  Toronto C10
# ..                                   ...          ...
# 542                9 Amaron Ave, Toronto  Toronto W10
# 543              35 Chilcot Ave, Toronto  Toronto W10
# 544          145 Silverstone Dr, Toronto  Toronto W10
# 545          107 Mount Olive Dr, Toronto  Toronto W10
# 546  8 & 10 Thistle Down Blvd E, Toronto  Toronto W10
#
#                              Community List_Price($)              Type  \
# 0                  Westminster-Branson      $989,000     Semi-Detached
# 1                      Oakwood-Vaughan      $999,900          Detached
# 2                   Humewood-Cedarvale    $1,038,000     Semi-Detached
# 3                      Oakwood-Vaughan    $1,145,000  Store w/Apt/Offc
# 4                  Mount Pleasant East    $1,149,000          Detached
# ..                                 ...           ...               ...
# 542      Thistletown-Beaumonde Heights    $1,049,900          Detached
# 543                   Elms-Old Rexdale    $1,199,999          Detached
# 544  Mount Olive-Silverstone-Jamestown    $1,231,000          Detached
# 545  Mount Olive-Silverstone-Jamestown    $1,279,000          Detached
# 546      Thistletown-Beaumonde Heights    $2,600,000     Semi-Detached
#
#             Style   BR   ER  WR FR  Kitchen  Gar_Type           AC Heat  \
# 0        Bungalow  4.0  2.0   2  N      2.0      None  Central Air  Gas
# 1        2-Storey  3.0  0.0   2  N      1.0  Detached  Window Unit  Gas
# 2        2-Storey  3.0  0.0   3  N      1.0      None  Central Air  Gas
# 3        2-Storey  3.0  0.0   3  N      3.0      None    Wall Unit  Gas
# 4        2-Storey  3.0  0.0   2  N      1.0      None  Central Air  Gas
# ..            ...  ...  ...  .. ..      ...       ...          ...  ...
# 542      Bungalow  3.0  1.0   3  Y      1.0  Detached  Central Air  Gas
# 543  1 1/2 Storey  3.0  2.0   2  Y      1.0  Detached  Central Air  Gas
# 544      Bungalow  4.0  2.0   2  Y      1.0  Detached  Central Air  Gas
# 545      2-Storey  4.0  1.0   3  N      1.0  Attached  Central Air  Gas
# 546      Bungalow  6.0  3.0   4  N      2.0      None  Central Air  Gas
#
#     Contract_Date                            Address_y                 Lat  \
# 0      2021-12-17             8 Virgilwood Dr, Toronto           43.773367
# 1      2022-01-09        213 Northcliffe Blvd, Toronto        43.682526175
# 2      2022-01-10             144 Winnett Ave, Toronto         43.68782725
# 3      2021-10-13             357 Oakwood Ave, Toronto         43.68699204
# 4      2022-01-11               82 Petman Ave, Toronto   43.70916151428571
# ..            ...                                  ...                 ...
# 542    2022-01-10                9 Amaron Ave, Toronto       43.7418921625
# 543    2021-11-27              35 Chilcot Ave, Toronto          43.7141594
# 544    2022-01-07          145 Silverstone Dr, Toronto  43.751753671986975
# 545    2022-01-08          107 Mount Olive Dr, Toronto          43.7462574
# 546    2022-01-10  8 & 10 Thistle Down Blvd E, Toronto  40.360960649999996
#
#                     Lng
# 0           -79.4485395
# 1           -79.4422434
# 2          -79.43277225
# 3          -79.43844438
# 4    -79.38486365714286
# ..                  ...
# 542      -79.5787170875
# 543         -79.5488803
# 544  -79.59027921260754
# 545         -79.5919673
# 546         116.0158654
#
# [547 rows x 18 columns]

# %%
merge2_df.drop(['Address_x'], axis=1, inplace=True)
merge2_df= merge2_df.rename(columns={'Address_y': 'Address'})
merge2_df
# Out:
#     Municipality                          Community List_Price($)  \
# 0    Toronto C07                Westminster-Branson      $989,000
# 1    Toronto C03                    Oakwood-Vaughan      $999,900
# 2    Toronto C03                 Humewood-Cedarvale    $1,038,000
# 3    Toronto C03                    Oakwood-Vaughan    $1,145,000
# 4    Toronto C10                Mount Pleasant East    $1,149,000
# ..           ...                                ...           ...
# 542  Toronto W10      Thistletown-Beaumonde Heights    $1,049,900
# 543  Toronto W10                   Elms-Old Rexdale    $1,199,999
# 544  Toronto W10  Mount Olive-Silverstone-Jamestown    $1,231,000
# 545  Toronto W10  Mount Olive-Silverstone-Jamestown    $1,279,000
# 546  Toronto W10      Thistletown-Beaumonde Heights    $2,600,000
#
#                  Type         Style   BR   ER  WR FR  Kitchen  Gar_Type  \
# 0       Semi-Detached      Bungalow  4.0  2.0   2  N      2.0      None
# 1            Detached      2-Storey  3.0  0.0   2  N      1.0  Detached
# 2       Semi-Detached      2-Storey  3.0  0.0   3  N      1.0      None
# 3    Store w/Apt/Offc      2-Storey  3.0  0.0   3  N      3.0      None
# 4            Detached      2-Storey  3.0  0.0   2  N      1.0      None
# ..                ...           ...  ...  ...  .. ..      ...       ...
# 542          Detached      Bungalow  3.0  1.0   3  Y      1.0  Detached
# 543          Detached  1 1/2 Storey  3.0  2.0   2  Y      1.0  Detached
# 544          Detached      Bungalow  4.0  2.0   2  Y      1.0  Detached
# 545          Detached      2-Storey  4.0  1.0   3  N      1.0  Attached
# 546     Semi-Detached      Bungalow  6.0  3.0   4  N      2.0      None
#
#               AC Heat Contract_Date                              Address  \
# 0    Central Air  Gas    2021-12-17             8 Virgilwood Dr, Toronto
# 1    Window Unit  Gas    2022-01-09        213 Northcliffe Blvd, Toronto
# 2    Central Air  Gas    2022-01-10             144 Winnett Ave, Toronto
# 3      Wall Unit  Gas    2021-10-13             357 Oakwood Ave, Toronto
# 4    Central Air  Gas    2022-01-11               82 Petman Ave, Toronto
# ..           ...  ...           ...                                  ...
# 542  Central Air  Gas    2022-01-10                9 Amaron Ave, Toronto
# 543  Central Air  Gas    2021-11-27              35 Chilcot Ave, Toronto
# 544  Central Air  Gas    2022-01-07          145 Silverstone Dr, Toronto
# 545  Central Air  Gas    2022-01-08          107 Mount Olive Dr, Toronto
# 546  Central Air  Gas    2022-01-10  8 & 10 Thistle Down Blvd E, Toronto
#
#                     Lat                 Lng
# 0             43.773367         -79.4485395
# 1          43.682526175         -79.4422434
# 2           43.68782725        -79.43277225
# 3           43.68699204        -79.43844438
# 4     43.70916151428571  -79.38486365714286
# ..                  ...                 ...
# 542       43.7418921625      -79.5787170875
# 543          43.7141594         -79.5488803
# 544  43.751753671986975  -79.59027921260754
# 545          43.7462574         -79.5919673
# 546  40.360960649999996         116.0158654
#
# [547 rows x 17 columns]

# %%
merge2_df['List_Price($)'] = merge2_df['List_Price($)'].replace('[\$,]', '', regex=True).astype(float)
merge2_df=merge2_df.dropna()
merge2_df.isnull().sum()
# Out:
# Municipality     0
# Community        0
# List_Price($)    0
# Type             0
# Style            0
# BR               0
# ER               0
# WR               0
# FR               0
# Kitchen          0
# Gar_Type         0
# AC               0
# Heat             0
# Contract_Date    0
# Address          0
# Lat              0
# Lng              0
# dtype: int64

# %%
merge2_df["Lng"] = pd.to_numeric(merge2_df["Lng"])
merge2_df["Lat"] = pd.to_numeric(merge2_df["Lat"])
merge2_df.dtypes
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Municipality             object
# Community                object
# List_Price($)           float64
# Type                     object
# Style                    object
# BR                      float64
# ER                      float64
# WR                        int64
# FR                       object
# Kitchen                 float64
# Gar_Type                 object
# AC                       object
# Heat                     object
# Contract_Date    datetime64[ns]
# Address                  object
# Lat                     float64
# Lng                     float64
# dtype: object

# %%
z=[]
for i in merge2_df['Contract_Date']:
    y = time.mktime(i.timetuple())
    z.append(y)
    
merge2_df['Contract_Date']=z
merge2_df
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Municipality                          Community  List_Price($)  \
# 0    Toronto C07                Westminster-Branson       989000.0
# 1    Toronto C03                    Oakwood-Vaughan       999900.0
# 2    Toronto C03                 Humewood-Cedarvale      1038000.0
# 3    Toronto C03                    Oakwood-Vaughan      1145000.0
# 4    Toronto C10                Mount Pleasant East      1149000.0
# ..           ...                                ...            ...
# 542  Toronto W10      Thistletown-Beaumonde Heights      1049900.0
# 543  Toronto W10                   Elms-Old Rexdale      1199999.0
# 544  Toronto W10  Mount Olive-Silverstone-Jamestown      1231000.0
# 545  Toronto W10  Mount Olive-Silverstone-Jamestown      1279000.0
# 546  Toronto W10      Thistletown-Beaumonde Heights      2600000.0
#
#                  Type         Style   BR   ER  WR FR  Kitchen  Gar_Type  \
# 0       Semi-Detached      Bungalow  4.0  2.0   2  N      2.0      None
# 1            Detached      2-Storey  3.0  0.0   2  N      1.0  Detached
# 2       Semi-Detached      2-Storey  3.0  0.0   3  N      1.0      None
# 3    Store w/Apt/Offc      2-Storey  3.0  0.0   3  N      3.0      None
# 4            Detached      2-Storey  3.0  0.0   2  N      1.0      None
# ..                ...           ...  ...  ...  .. ..      ...       ...
# 542          Detached      Bungalow  3.0  1.0   3  Y      1.0  Detached
# 543          Detached  1 1/2 Storey  3.0  2.0   2  Y      1.0  Detached
# 544          Detached      Bungalow  4.0  2.0   2  Y      1.0  Detached
# 545          Detached      2-Storey  4.0  1.0   3  N      1.0  Attached
# 546     Semi-Detached      Bungalow  6.0  3.0   4  N      2.0      None
#
#               AC Heat  Contract_Date                              Address  \
# 0    Central Air  Gas   1.639717e+09             8 Virgilwood Dr, Toronto
# 1    Window Unit  Gas   1.641704e+09        213 Northcliffe Blvd, Toronto
# 2    Central Air  Gas   1.641791e+09             144 Winnett Ave, Toronto
# 3      Wall Unit  Gas   1.634098e+09             357 Oakwood Ave, Toronto
# 4    Central Air  Gas   1.641877e+09               82 Petman Ave, Toronto
# ..           ...  ...            ...                                  ...
# 542  Central Air  Gas   1.641791e+09                9 Amaron Ave, Toronto
# 543  Central Air  Gas   1.637989e+09              35 Chilcot Ave, Toronto
# 544  Central Air  Gas   1.641532e+09          145 Silverstone Dr, Toronto
# 545  Central Air  Gas   1.641618e+09          107 Mount Olive Dr, Toronto
# 546  Central Air  Gas   1.641791e+09  8 & 10 Thistle Down Blvd E, Toronto
#
#            Lat         Lng
# 0    43.773367  -79.448539
# 1    43.682526  -79.442243
# 2    43.687827  -79.432772
# 3    43.686992  -79.438444
# 4    43.709162  -79.384864
# ..         ...         ...
# 542  43.741892  -79.578717
# 543  43.714159  -79.548880
# 544  43.751754  -79.590279
# 545  43.746257  -79.591967
# 546  40.360961  116.015865
#
# [530 rows x 17 columns]

# %%
merge2_df.drop(['Address'], inplace=True, axis=1)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
cat = merge2_df.dtypes[model_df.dtypes == "object"].index.tolist()
cat
# Out:
# ['Municipality', 'Community', 'Type', 'Style', 'FR', 'Gar_Type', 'AC', 'Heat']

# %%
encode2_df = pd.DataFrame(enc.fit_transform(merge2_df[cat]))

# Add the encoded variable names to the DataFrame
encode2_df.columns = merge2_df[cat].columns
encode2_df.head()
# Out:
#    Municipality  Community  Type  Style   FR  Gar_Type   AC  Heat
# 0           5.0      111.0   6.0    8.0  0.0       4.0  0.0   1.0
# 1           2.0       86.0   1.0    2.0  0.0       3.0  4.0   1.0
# 2           2.0       53.0   6.0    2.0  0.0       4.0  0.0   1.0
# 3           2.0       86.0   7.0    2.0  0.0       4.0  3.0   1.0
# 4           8.0       78.0   1.0    2.0  0.0       4.0  0.0   1.0

# %%
final2_df = merge2_df.merge(encode2_df,left_index=True, right_index=True)
final2_df
# Out:
#     Municipality_x                 Community_x  List_Price($)  \
# 0      Toronto C07         Westminster-Branson       989000.0
# 1      Toronto C03             Oakwood-Vaughan       999900.0
# 2      Toronto C03          Humewood-Cedarvale      1038000.0
# 3      Toronto C03             Oakwood-Vaughan      1145000.0
# 4      Toronto C10         Mount Pleasant East      1149000.0
# ..             ...                         ...            ...
# 525    Toronto W08  Islington-City Centre West      3333000.0
# 526    Toronto W09              Humber Heights      3350000.0
# 527    Toronto W08    Edenbridge-Humber Valley      3399000.0
# 528    Toronto W08  Islington-City Centre West      3475000.0
# 529    Toronto W04                  Maple Leaf      3499000.0
#
#                Type_x   Style_x   BR   ER  WR FR_x  Kitchen  ...        Lat  \
# 0       Semi-Detached  Bungalow  4.0  2.0   2    N      2.0  ...  43.773367
# 1            Detached  2-Storey  3.0  0.0   2    N      1.0  ...  43.682526
# 2       Semi-Detached  2-Storey  3.0  0.0   3    N      1.0  ...  43.687827
# 3    Store w/Apt/Offc  2-Storey  3.0  0.0   3    N      3.0  ...  43.686992
# 4            Detached  2-Storey  3.0  0.0   2    N      1.0  ...  43.709162
# ..                ...       ...  ...  ...  ..  ...      ...  ...        ...
# 525          Detached  2-Storey  5.0  1.0   5    Y      1.0  ...  43.653495
# 526          Detached  2-Storey  4.0  0.0   5    Y      1.0  ...  43.691898
# 527          Detached  2-Storey  4.0  1.0   5    Y      1.0  ...  43.653329
# 528          Detached  2-Storey  4.0  0.0   6    N      1.0  ...  43.647240
# 529          Detached  2-Storey  4.0  2.0   5    Y      1.0  ...  43.719016
#
#            Lng Municipality_y  Community_y  Type_y  Style_y  FR_y  Gar_Type_y  \
# 0   -79.448539            5.0        111.0     6.0      8.0   0.0         4.0
# 1   -79.442243            2.0         86.0     1.0      2.0   0.0         3.0
# 2   -79.432772            2.0         53.0     6.0      2.0   0.0         4.0
# 3   -79.438444            2.0         86.0     7.0      2.0   0.0         4.0
# 4   -79.384864            8.0         78.0     1.0      2.0   0.0         4.0
# ..         ...            ...          ...     ...      ...   ...         ...
# 525 -79.558824           34.0        106.0     1.0      8.0   1.0         3.0
# 526 -79.530231           34.0         38.0     1.0      0.0   1.0         3.0
# 527 -79.526426           34.0         77.0     1.0      8.0   1.0         3.0
# 528 -79.537315           34.0         77.0     1.0      2.0   0.0         0.0
# 529 -79.486950           34.0        106.0     6.0      8.0   0.0         4.0
#
#      AC_y  Heat_y
# 0     0.0     1.0
# 1     4.0     1.0
# 2     0.0     1.0
# 3     3.0     1.0
# 4     0.0     1.0
# ..    ...     ...
# 525   0.0     1.0
# 526   0.0     1.0
# 527   0.0     1.0
# 528   0.0     1.0
# 529   0.0     1.0
#
# [514 rows x 24 columns]

# %%
final2_df = final2_df.drop(['Municipality_x', 'Community_x', 'Type_x', 'Style_x', 'FR_x', 'Gar_Type_x', 'AC_x', 'Heat_x'] ,1)
# Out:
# /Users/taimurahmadkhan/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
final2_df
# Out:
#      List_Price($)   BR   ER  WR  Kitchen  Contract_Date        Lat  \
# 0         989000.0  4.0  2.0   2      2.0   1.639717e+09  43.773367
# 1         999900.0  3.0  0.0   2      1.0   1.641704e+09  43.682526
# 2        1038000.0  3.0  0.0   3      1.0   1.641791e+09  43.687827
# 3        1145000.0  3.0  0.0   3      3.0   1.634098e+09  43.686992
# 4        1149000.0  3.0  0.0   2      1.0   1.641877e+09  43.709162
# ..             ...  ...  ...  ..      ...            ...        ...
# 525      3333000.0  5.0  1.0   5      1.0   1.636952e+09  43.653495
# 526      3350000.0  4.0  0.0   5      1.0   1.630555e+09  43.691898
# 527      3399000.0  4.0  1.0   5      1.0   1.634702e+09  43.653329
# 528      3475000.0  4.0  0.0   6      1.0   1.641445e+09  43.647240
# 529      3499000.0  4.0  2.0   5      1.0   1.627272e+09  43.719016
#
#            Lng  Municipality_y  Community_y  Type_y  Style_y  FR_y  \
# 0   -79.448539             5.0        111.0     6.0      8.0   0.0
# 1   -79.442243             2.0         86.0     1.0      2.0   0.0
# 2   -79.432772             2.0         53.0     6.0      2.0   0.0
# 3   -79.438444             2.0         86.0     7.0      2.0   0.0
# 4   -79.384864             8.0         78.0     1.0      2.0   0.0
# ..         ...             ...          ...     ...      ...   ...
# 525 -79.558824            34.0        106.0     1.0      8.0   1.0
# 526 -79.530231            34.0         38.0     1.0      0.0   1.0
# 527 -79.526426            34.0         77.0     1.0      8.0   1.0
# 528 -79.537315            34.0         77.0     1.0      2.0   0.0
# 529 -79.486950            34.0        106.0     6.0      8.0   0.0
#
#      Gar_Type_y  AC_y  Heat_y
# 0           4.0   0.0     1.0
# 1           3.0   4.0     1.0
# 2           4.0   0.0     1.0
# 3           4.0   3.0     1.0
# 4           4.0   0.0     1.0
# ..          ...   ...     ...
# 525         3.0   0.0     1.0
# 526         3.0   0.0     1.0
# 527         3.0   0.0     1.0
# 528         0.0   0.0     1.0
# 529         4.0   0.0     1.0
#
# [514 rows x 16 columns]

# %%
X = final2_df.values
len(X)
# Out:
# 514

# %%
X_test_scaled2 = X_scaler.transform(X)

# %%
# use trained model to predict this data
y_predd2 = regressor.predict(X_test_scaled2)
df2 = pd.DataFrame({'Predicted': y_predd2})
df2
# Out:
#         Predicted
# 0    1.192135e+06
# 1    1.244908e+06
# 2    1.288386e+06
# 3    1.321584e+06
# 4    1.368854e+06
# ..            ...
# 509  3.284454e+06
# 510  3.290020e+06
# 511  3.323739e+06
# 512  3.421210e+06
# 513  3.404828e+06
#
# [514 rows x 1 columns]

# %%
alpha_df=final2_df.merge(df2, how='inner', left_index=True, right_index=True)
alpha_df
# Out:
#      List_Price($)   BR   ER  WR  Kitchen  Contract_Date        Lat  \
# 0         989000.0  4.0  2.0   2      2.0   1.639717e+09  43.773367
# 1         999900.0  3.0  0.0   2      1.0   1.641704e+09  43.682526
# 2        1038000.0  3.0  0.0   3      1.0   1.641791e+09  43.687827
# 3        1145000.0  3.0  0.0   3      3.0   1.634098e+09  43.686992
# 4        1149000.0  3.0  0.0   2      1.0   1.641877e+09  43.709162
# ..             ...  ...  ...  ..      ...            ...        ...
# 509      2649900.0  4.0  0.0   5      1.0   1.638508e+09  43.599122
# 510      2688800.0  4.0  4.0   5      3.0   1.622693e+09  43.675932
# 511      2799000.0  5.0  2.0   3      3.0   1.635480e+09  43.663244
# 512      2800000.0  6.0  0.0   2      2.0   1.635998e+09  43.672840
# 513      2899000.0  5.0  1.0   5      1.0   1.641877e+09  43.728183
#
#            Lng  Municipality_y  Community_y  Type_y  Style_y  FR_y  \
# 0   -79.448539             5.0        111.0     6.0      8.0   0.0
# 1   -79.442243             2.0         86.0     1.0      2.0   0.0
# 2   -79.432772             2.0         53.0     6.0      2.0   0.0
# 3   -79.438444             2.0         86.0     7.0      2.0   0.0
# 4   -79.384864             8.0         78.0     1.0      2.0   0.0
# ..         ...             ...          ...     ...      ...   ...
# 509 -79.508142            32.0         55.0     1.0      2.0   1.0
# 510 -79.452903            33.0         49.0     1.0      2.0   1.0
# 511 -79.501328            32.0         37.0     1.0      2.0   1.0
# 512 -79.443831            32.0         55.0     1.0      2.0   0.0
# 513 -79.236526            28.0         71.0     1.0      2.0   1.0
#
#      Gar_Type_y  AC_y  Heat_y     Predicted
# 0           4.0   0.0     1.0  1.192135e+06
# 1           3.0   4.0     1.0  1.244908e+06
# 2           4.0   0.0     1.0  1.288386e+06
# 3           4.0   3.0     1.0  1.321584e+06
# 4           4.0   0.0     1.0  1.368854e+06
# ..          ...   ...     ...           ...
# 509         1.0   0.0     1.0  3.284454e+06
# 510         1.0   0.0     1.0  3.290020e+06
# 511         0.0   0.0     1.0  3.323739e+06
# 512         1.0   0.0     1.0  3.421210e+06
# 513         1.0   0.0     1.0  3.404828e+06
#
# [498 rows x 17 columns]

# %%
alpha1_df=alpha_df[['List_Price($)','Predicted']]
alpha1_df
# Out:
#      List_Price($)     Predicted
# 0         989000.0  1.192135e+06
# 1         999900.0  1.244908e+06
# 2        1038000.0  1.288386e+06
# 3        1145000.0  1.321584e+06
# 4        1149000.0  1.368854e+06
# ..             ...           ...
# 509      2649900.0  3.284454e+06
# 510      2688800.0  3.290020e+06
# 511      2799000.0  3.323739e+06
# 512      2800000.0  3.421210e+06
# 513      2899000.0  3.404828e+06
#
# [498 rows x 2 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
alpha1_df
# Out:
#      List_Price($)     Predicted
# 0     989000.00000 1192134.84738
# 1     999900.00000 1244907.52888
# 2    1038000.00000 1288386.27409
# 3    1145000.00000 1321583.79209
# 4    1149000.00000 1368853.73164
# ..             ...           ...
# 509  2649900.00000 3284454.11253
# 510  2688800.00000 3290020.44623
# 511  2799000.00000 3323739.22875
# 512  2800000.00000 3421210.01654
# 513  2899000.00000 3404828.46051
#
# [498 rows x 2 columns]
